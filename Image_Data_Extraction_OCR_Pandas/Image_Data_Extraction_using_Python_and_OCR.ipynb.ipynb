# %%
#Load images in jupyter notebook using Python Libraries #

# %%
✅ 1. Images

You can load and display images using libraries like:
	•	matplotlib
	•	PIL (Pillow)
	•	OpenCV

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/Users/akbarbasha/Desktop/Table format view.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# !pip install pytesseract # Python library to read content/data from images #
'''
Use pytesseract (Python wrapper for Google’s Tesseract OCR):

🧠 Optional: Use EasyOCR for advanced data and table extractions:

If the image contains a complex table layout, try:

pip install easyocr

'''

# %%
#Use pytesseract (Python wrapper for Google’s Tesseract OCR):#
import pytesseract
from PIL import Image
img = Image.open("/Users/akbarbasha/Desktop/Table format view.jpg")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# we Ts
# | | | | | | | | |
# + + + + + + + +: +:
# | 2 | User_1 | 6@ | user1@example.com | Paris | Germany | 2022-07-26 | 1 | 23.17 | Gold |
# | 2 | User_2 | 38 | user2@example.com | New York | USA | 2020-07-26 | ® | 86.01 | Premium |
# | 3 | User_3 | 23 | user3@example.com | Tokyo | Japan | 2020-11-23 | @ | 21.23 | Basic |
# | 4 | User_4 | 49 | user4@example.com | Berlin | France | 2020-@6-12 | 1 | 97.88 | Platinum |
# | 5 | User_5 | 52 | user5@example.com | London | UK | 2021-03-19 | 1 | 11.09 | Gold |
# | 6 | User_6 | 33 | user6@example.com | Paris | Germany | 2021-11-2e | @ | 63.47 | Basic |
# aan : 5 eae ni i - RE ee ee. fee can ees ec :

# %%
'''
means that the Tesseract OCR engine is not installed on your system, or it’s installed but your Python environment 
(e.g., Jupyter) cannot find it via the system PATH.

✅ Solution Steps

🔧 1. Install Tesseract OCR

On macOS (M1/M2/M3):
brew install tesseract in terminal window -Installed Check version - tesseract --version

#This fixed the issue# We need to install the google tesseract ocr in our terminal post that execute the above code#

# %%
# !pip install tesseract

# %%
# !pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached python_bidi-0.6.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# ...
#   Using cached shapely-2.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# ...
#   Using cached pyclipper-1.3.0.post6-cp312-cp312-macosx_10_13_universal2.whl.metadata (9.0 kB)
# ...
#   Using cached ninja-1.11.1.4-py3-none-macosx_10_9_universal2.whl.metadata (5.0 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/Users/akbarbasha/Desktop/Beverages.jpg")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import pytesseract
from PIL import Image
img = Image.open("/Users/akbarbasha/Desktop/Beverages.jpg")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# MARKET
#
# Ready-to-Drink
#
# Beverages Market eee
#
# Billion
#
# to grow at $804.87
# 6.22% $766.69 Billion
# CAGR Billion
#
# during saad
# 2025-2032
#
# INDUSTRY DEVELOPMENT
#
# Tata Consumer Products launched the
# ready-to-drink juice & jelly combination
# beverage product "Tata Fruski”.
#
# ASIA PACIFIC
#
# $258.99 $273.55
# Billion Billion
# 2023 2024
#
# North America | South America
# Middle East & Africa | Europe
#
# READY-TO-DRINK BEVERAGES
#
# TRENDS
#
# Research & Development and
# New Product Launches to Push
# the RTD Beverages Demand
#
# DRIVERS
#
# Spotlight on Gut Health Improvement
# and Functional Beverages
#
# Premiumization & Diversified Flavours
#
# BY DISTRIBUTION
# CHANNEL
#
# Specialty Stores 8.98%
#
# ASIA PACIFIC
# BY DISTRIBUTION
# CHANNEL
#
# Specialty Stores 6.89%
#
# BY PRODUCT TYPE
#
# Fermented Beverages
#
# Non-Fermented Beverages
#
# Alcoholic Beverages

# %%
import pandas as pd

# Market Forecast
market_data = pd.DataFrame({
    "Region": ["Asia Pacific"],
    "Market Size 2023": ["$258.99 Billion"],
    "Market Size 2024": ["$273.55 Billion"],
    "Forecast CAGR": ["6.22%"],
    "Forecast Value (2032)": ["$804.87 Billion"]
})

# Distribution Channels
global_dist = pd.DataFrame({"Channel": ["Specialty Stores"], "Market Share": ["8.98%"]})
asia_dist = pd.DataFrame({"Channel": ["Specialty Stores"], "Market Share": ["6.89%"]})

# Product Types
product_types = pd.DataFrame({
    "Product Type": ["Fermented Beverages", "Non-Fermented Beverages", "Alcoholic Beverages"]
})

# Industry Development
industry_dev = pd.DataFrame({
    "Company": ["Tata Consumer Products"],
    "Development": ['Launched ready-to-drink juice & jelly combo "Tata Fruski"']
})

# Drivers & Trends (You may store these as strings or lists depending on analysis needs)
trends = ["R&D and New Product Launches to Push RTD Beverages Demand"]
drivers = [
    "Spotlight on Gut Health Improvement",
    "Functional Beverages",
    "Premiumization & Diversified Flavours"
]

# %%
from IPython.display import display

display(market_data)
# Out:
#          Region Market Size 2023 Market Size 2024 Forecast CAGR  \
# 0  Asia Pacific  $258.99 Billion  $273.55 Billion         6.22%
#
#   Forecast Value (2032)
# 0       $804.87 Billion

# %%
display(global_dist)
# Out:
#             Channel Market Share
# 0  Specialty Stores        8.98%

# %%
display(product_types)
# Out:
#               Product Type
# 0      Fermented Beverages
# 1  Non-Fermented Beverages
# 2      Alcoholic Beverages
