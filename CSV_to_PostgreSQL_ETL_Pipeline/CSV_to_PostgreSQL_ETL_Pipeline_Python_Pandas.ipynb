# %%
#step:1 Importing csv file using python pandas library#
import pandas as pd
from sqlalchemy import create_engine

csv_data = pd.read_csv("/Users/akbarbasha/Desktop/Healthdata/patient_health_data 2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[12], line 5
#       2 import pandas as pd
#       3 from sqlalchemy import create_engine
# ----> 5 csv_data = pd.read_csv("/Users/akbarbasha/Desktop/Healthdata/patient_health_data 2.xlsx")
#
# ...

# %%
#step:2 Create a connecting string with jupyter notebook + postgres to load the imported data from jupyter to postgre
#Here we specify the database name credentails to establish connection between jupyter + postgres #
#install all necessay=ry postgres and python libraries#
# !pip install psycopg2-binary;
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Step: 3 Create connection string
conn_str = f"postgresql+psycopg2://postgres:seagate@localhost:5432/postgres"
engine = create_engine(conn_str)

#step 4:Input valid database credentials
username = "postgres"
password = "seagate"
host = "localhost"
port = "5432"
database = "postgres"

# %%
# Step 5: Data Transformation 
#csv_data.shape #Find out no of rows and columns #

csv_data.isnull().sum() # To find out misisng values which and represnted as nan #
# Out:
# patient_id               0
# name                     0
# age                      0
# gender                   0
# weight_kg                0
# height_cm                0
# bmi                      0
# systolic_bp              0
# diastolic_bp             0
# heart_rate               0
# blood_glucose            0
# cholesterol              0
# diagnosis                0
# medication             184
# doctor                   0
# hospital                 0
# visit_date               0
# follow_up_required       0
# insurance_provider       0
# notes                    0
# heart_rate_category      0
# dtype: int64

# %%
#Step 6: Push DataFrame to PostgreSQL as a new table#
csv_data.to_sql("patient_info", engine, if_exists="replace", index=False)
# Out:
# 1000

# %%
csv_data.columns
# Out:
# Index(['patient_id', 'name', 'age', 'gender', 'weight_kg', 'height_cm', 'bmi',
#        'systolic_bp', 'diastolic_bp', 'heart_rate', 'blood_glucose',
#        'cholesterol', 'diagnosis', 'medication', 'doctor', 'hospital',
#        'visit_date', 'follow_up_required', 'insurance_provider', 'notes',
#        'heart_rate_category'],
#       dtype='object')
